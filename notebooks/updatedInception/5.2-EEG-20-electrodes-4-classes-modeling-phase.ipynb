# %% [markdown]
# # Feature Extraction Phase
# In this notebook I'm running the feature extraction phase using an Inception Convolutional Neural Network as the feature extraction model trained with the pre-processed data as well as optimized with a Bayesian Optimization process.
#
# **Author**: Arthur G.

# %% [markdown]
# ## Loading Dependencies
# Loading and setting up all the dependencies for this notebook.

# %%
# libs
import os
import time
import warnings

import numpy as np
import pandas as pd
import tensorflow as tf
from pycaret.classification import *
from keras_tuner import HyperModel, Objective
from keras_tuner.tuners import BayesianOptimization
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report
from sklearn import metrics
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

# settings
seed = np.random.seed(42)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Helper Functions
# A set of helper functions and classes for the automation of model optimization.

# %%
class InceptionHyperModel(HyperModel):
    """Builds the base Inception model for dynamic optimization."""
    
    def build(self, hp):
        """Initiate the model before the bayesian process gets started."""
        input_tensor = tf.keras.layers.Input(shape=(1, 300, 20)) # era 1,300,1

        
        # bottleneck layer
        x = tf.keras.layers.Conv2D(
                filters=hp.Int("n_filters_1_bn", min_value=16, max_value=64, step=16), 
                kernel_size=(1, 1), 
                strides=1, 
                padding='same', 
                activation='relu'
        )(input_tensor)
        x = tf.keras.layers.Conv2D(
                filters=hp.Int("n_filters_2_bn", min_value=16, max_value=64, step=16), 
                kernel_size=hp.Int("kernel_size_bn", min_value=2, max_value=4, step=1), 
                strides=1, 
                padding='same', 
                activation='relu'
        )(x)
        x = tf.keras.layers.Conv2D(
                filters=hp.Int("n_filters_3_bn", min_value=16, max_value=64, step=16), 
                kernel_size=(1, 1), 
                strides=1, 
                padding='same', 
                activation='relu'
        )(x)
        x = tf.keras.layers.Dropout(
                hp.Choice("dropout_rate_bn", values=[0.05, 0.5], default=0.5)
        )(x)
        

        # dynamic efficient inception blocks
        for i in range(hp.Int("n_incep_blocks", min_value=2, max_value=4, step=1)):
            x = tf.keras.layers.Conv2D(
                    filters=hp.Int("n_filters_1_ib", min_value=16, max_value=64, step=16), 
                    kernel_size=(1, 1), 
                    padding="same", 
                    activation="relu"
            )(x)
            x = tf.keras.layers.Conv2D(
                    filters=hp.Int("n_filters_2_ib", min_value=16, max_value=64, step=16), 
                    kernel_size=(1, 1), 
                    padding="same", 
                    activation="relu"
            )(x)
            x = tf.keras.layers.Conv2D(
                    filters=hp.Int("n_filters_3_ib", min_value=16, max_value=64, step=16), 
                    kernel_size=(3, 3), 
                    padding="same", 
                    activation="relu"
            )(x)
            x = tf.keras.layers.Conv2D(
                    filters=hp.Int("n_filters_4_ib", min_value=16, max_value=64, step=16), 
                    kernel_size=(1, 1), 
                    padding="same", 
                    activation="relu"
            )(x)
            x = tf.keras.layers.Conv2D(
                    filters=hp.Int("n_filters_5_ib", min_value=16, max_value=64, step=16), 
                    kernel_size=(5, 5), 
                    padding="same", 
                    activation="relu"
            )(x)
            x = tf.keras.layers.MaxPooling2D(
                    pool_size=(3, 3), 
                    strides=(1, 1), 
                    padding='same'
            )(x)
            x = tf.keras.layers.Conv2D(
                filters=hp.Int("n_filters_6_ib", min_value=16, max_value=64, step=16), 
                kernel_size=(1, 1), 
                padding="same", 
                activation="relu"
            )(x)
        

        # fully connected layer
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        
        for i in range(hp.Int("n_fc_blocks", min_value=2, max_value=4, step=1)):
            x = tf.keras.layers.Dense(
                    units=hp.Int("n_dense_nodes_1_fc", min_value=32, max_value=256, step=32), 
                    activation='relu'
            )(x)
            x = tf.keras.layers.Dropout(
                    hp.Choice("dropout_rate_fc", values=[0.05, 0.5], default=0.5)
            )(x)
            x = tf.keras.layers.Dense(
                    units=hp.Int(
                        "n_dense_nodes_2_fc", min_value=32, max_value=256, step=32) \
                        // hp.Int("dense_nodes_div", min_value=2, max_value=8, step=2), 
                        activation='relu'
            )(x)
        
        output_tensor = tf.keras.layers.Dense(
            4, 
            activation='softmax'
        )(x)
        

        # model compilation
        model = tf.keras.Model(inputs=input_tensor, outputs=output_tensor)
        model.compile(
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'],
            optimizer=hp.Choice(
                "optimizer", 
                values=[
                    "sgd", "rmsprop", "adam", 
                    "adadelta", "adagrad", 
                    "adamax", "nadam"
                ], default="adam"
            )
        )
        
        return model
    

def get_features_extracted(model, final_layer: str, sample: np.ndarray):
    """
    This function extracts outputs from a given layer
    name.
    """
    sample = np.expand_dims(sample, axis=0)
    output = np.array(
        tf.keras.Model(inputs=model.inputs, outputs=model.get_layer(final_layer).output)(sample)
    )
    
    return output

# %% [markdown]
# ## Feature Extraction Pipeline
# Building the feature extraction pipeline using an Inception Convolutional Neural Network.

# %% [markdown]
# Loading and preparing the DCE-based dataset.

# %%
# loading data and targets
data = np.loadtxt(os.path.join("..","..", "data", "processed", "EEG_filt_20_electrodes.csv"), delimiter=',')
targets = np.loadtxt(os.path.join("..","..", "data", "processed", "EEG_filt_first_8_electrodes_targets.csv"), delimiter=',')

# encoding targets (from string to int)
targets[targets == 0] = 0
targets[targets == 1] = 1 # 19494 subjects of this class
targets[targets == 2] = 2
targets[targets == 3] = 3 # 11286 subjects of this class
targets = targets.astype(int)

print(f"Original data shape: {data.shape}")
data_reshape = data.reshape(10800, 1,300, 20) 

print(f"Reshaped data shape: {data_reshape.shape}")
print(f"Original targets shape: {targets.shape}")
# Out:
# Original data shape: (3240000, 20)
# Reshaped data shape: (10800, 1, 300, 20)
# Original targets shape: (10800,)

# %%
print(f"data: {data[3,1]}, data_reshape: {data_reshape[0,0,3,1]}")
data_reshape.shape
# Out:
# data: 65.4093722285802, data_reshape: 65.4093722285802
# (10800, 1, 300, 20)

# %% [markdown]
# ### Train-Test-Split
# Splitting DCE-based dataset into train/holdout sets.

# %%
x_train, x_holdout, y_train, y_holdout = train_test_split(
    data_reshape,
    targets,
    test_size=0.2,
    shuffle=True,
    random_state=seed
)

print(f"Original data train set: {x_train.shape}")
print(f"Holdout data test set: {x_holdout.shape}")
# Out:
# Original data train set: (8640, 1, 300, 20)
# Holdout data test set: (2160, 1, 300, 20)

# %% [markdown]
# ### Architecture Optimization
# Building the optimizable iCNN skeleton.

# %%
# loading the Inception skeleton
inception_hyper_model = InceptionHyperModel()

# %% [markdown]
# Setting up the architecture tuner.

# %%
# setting up the optimization process
tuner = BayesianOptimization(
    hypermodel=inception_hyper_model,
    objective="val_loss",
    num_initial_points=25,
    max_trials=15,
    directory=os.path.join("..","..", "models","updatedInception"),
    project_name="20_electrodes_4_classes_feature_extractor",
    seed=seed
)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ..\..\models\updatedInception\20_electrodes_4_classes_feature_extractor\oracle.json
# INFO:tensorflow:Reloading Tuner from ..\..\models\updatedInception\20_electrodes_4_classes_feature_extractor\tuner0.json

# %% [markdown]
# Defining callback functions.

# %%
# defining callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss', 
        patience=20
    ),
    ReduceLROnPlateau(
        monitor="val_loss", 
        factor=0.1, 
        patience=10, 
        mode="auto", 
        min_delta=0.0001, 
        cooldown=0, 
        min_lr=1.0e-6
    )
]

# %% [markdown]
# Running the tuner.

# %%
# running the search
tuner.search(
    x_train,
    y_train,
    epochs=250,
    validation_split=0.2,
    batch_size=32,
    callbacks=[callbacks]
)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# ### Building The Model
# Getting the best feature extraction model from the tuner.

# %%
best_feature_extractor = tuner.get_best_models(num_models=1)[0]

# %% [markdown]
# ### Feature Extraction Process
# Using the model to extract predictive patterns from the DCE-based dataset.

# %%
train_features = []
holdout_features = []

# extracting trian features
for sample in x_train:
    sample_features = get_features_extracted(best_feature_extractor, "global_average_pooling2d", sample)
    train_features.append(sample_features)
    
# extracting holdout features
for sample in x_holdout:
    sample_features = get_features_extracted(best_feature_extractor, "global_average_pooling2d", sample)
    holdout_features.append(sample_features)

# assembling feature dataframes
train_features_df = pd.DataFrame(np.array(train_features).reshape((len(train_features),len(train_features[0][0])))) 
train_features_df["CLASS"] = y_train

holdout_features_df = pd.DataFrame(np.array(holdout_features).reshape((len(holdout_features),len(holdout_features[0][0]))))
holdout_features_df["CLASS"] = y_holdout

print(f"Train dataset shape: {train_features_df.shape}")
print(f"Holdout dataset shape: {holdout_features_df.shape}")
# Out:
# Train dataset shape: (8640, 49)
# Holdout dataset shape: (2160, 49)

# %% [markdown]
# ## Machine Learning Classification Experiment
# Renaming the columns to avoid errors.

# %%
train_features_df.columns = train_features_df.columns.astype(str)
holdout_features_df.columns = holdout_features_df.columns.astype(str)

# %%
eval_result = best_feature_extractor.evaluate(x_holdout, y_holdout)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 68/68 [==============================] - 1s 15ms/step - loss: 0.2972 - accuracy: 0.9000
# [test loss, test accuracy]: [0.29721200466156006, 0.8999999761581421]

# %% [markdown]
# ##### Inception Statistics

# %%
y_pred = best_feature_extractor.predict(x_holdout, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(y_holdout, y_pred_bool,digits=4))

print('AUC = %.4f' % metrics.roc_auc_score(y_holdout, y_pred,  multi_class="ovr", average='macro'))
# Out:
# 34/34 [==============================] - 1s 22ms/step
#               precision    recall  f1-score   support
#
#            0     0.9469    0.8770    0.9106       244
#            1     0.9242    0.9465    0.9352      1159
#            2     0.8323    0.8169    0.8245       486
#            3     0.8741    0.8708    0.8725       271
#
#     accuracy                         0.9000      2160
#    macro avg     0.8944    0.8778    0.8857      2160
# weighted avg     0.8998    0.9000    0.8997      2160
#
# AUC = 0.9817

# %% [markdown]
# Setting up the ML classification pipeline.

# %%
classif_exp = setup(
    data=train_features_df,
    test_data=holdout_features_df,
    target="CLASS",
    fold_shuffle=True,
    preprocess = False,
    use_gpu=True
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4702c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4702c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4702c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4702c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4702c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4702c_row0_col1" class="data row0 col1" >1720</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4702c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4702c_row1_col1" class="data row1 col1" >CLASS</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4702c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4702c_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4702c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4702c_row3_col1" class="data row3 col1" >(10800, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4702c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4702c_row4_col1" class="data row4 col1" >(10800, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4702c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4702c_row5_col1" class="data row5 col1" >(8640, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4702c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4702c_row6_col1" class="data row6 col1" >(2160, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_4702c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4702c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4702c_row7_col1" class="data row7 col1" >48</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Models Comparison
# Comparing different machine learning model performances for the task of classifying DCE-base features.

# %%
best_model = compare_models(sort="Accuracy")
# Out:
# <style type="text/css">
# #T_c7e83 th {
#   text-align: left;
# }
# #T_c7e83_row0_col0, #T_c7e83_row0_col2, #T_c7e83_row0_col4, #T_c7e83_row0_col6, #T_c7e83_row0_col7, #T_c7e83_row1_col0, #T_c7e83_row2_col0, #T_c7e83_row2_col1, #T_c7e83_row2_col3, #T_c7e83_row2_col4, #T_c7e83_row2_col5, #T_c7e83_row2_col6, #T_c7e83_row2_col7, #T_c7e83_row3_col0, #T_c7e83_row3_col1, #T_c7e83_row3_col2, #T_c7e83_row3_col3, #T_c7e83_row3_col4, #T_c7e83_row3_col5, #T_c7e83_row3_col6, #T_c7e83_row3_col7, #T_c7e83_row4_col0, #T_c7e83_row4_col1, #T_c7e83_row4_col2, #T_c7e83_row4_col3, #T_c7e83_row4_col4, #T_c7e83_row4_col5, #T_c7e83_row4_col6, #T_c7e83_row4_col7, #T_c7e83_row5_col0, #T_c7e83_row5_col1, #T_c7e83_row5_col2, #T_c7e83_row5_col3, #T_c7e83_row5_col4, #T_c7e83_row5_col5, #T_c7e83_row5_col6, #T_c7e83_row5_col7, #T_c7e83_row6_col0, #T_c7e83_row6_col1, #T_c7e83_row6_col2, #T_c7e83_row6_col3, #T_c7e83_row6_col4, #T_c7e83_row6_col5, #T_c7e83_row6_col6, #T_c7e83_row6_col7, #T_c7e83_row7_col0, #T_c7e83_row7_col1, #T_c7e83_row7_col2, #T_c7e83_row7_col3, #T_c7e83_row7_col4, #T_c7e83_row7_col5, #T_c7e83_row7_col6, #T_c7e83_row7_col7, #T_c7e83_row8_col0, #T_c7e83_row8_col1, #T_c7e83_row8_col2, #T_c7e83_row8_col3, #T_c7e83_row8_col4, #T_c7e83_row8_col5, #T_c7e83_row8_col6, #T_c7e83_row8_col7, #T_c7e83_row9_col0, #T_c7e83_row9_col1, #T_c7e83_row9_col2, #T_c7e83_row9_col3, #T_c7e83_row9_col4, #T_c7e83_row9_col5, #T_c7e83_row9_col6, #T_c7e83_row9_col7, #T_c7e83_row10_col0, #T_c7e83_row10_col1, #T_c7e83_row10_col2, #T_c7e83_row10_col3, #T_c7e83_row10_col4, #T_c7e83_row10_col5, #T_c7e83_row10_col6, #T_c7e83_row10_col7, #T_c7e83_row11_col0, #T_c7e83_row11_col1, #T_c7e83_row11_col2, #T_c7e83_row11_col3, #T_c7e83_row11_col4, #T_c7e83_row11_col5, #T_c7e83_row11_col6, #T_c7e83_row11_col7, #T_c7e83_row12_col0, #T_c7e83_row12_col1, #T_c7e83_row12_col2, #T_c7e83_row12_col3, #T_c7e83_row12_col4, #T_c7e83_row12_col5, #T_c7e83_row12_col6, #T_c7e83_row12_col7, #T_c7e83_row13_col0, #T_c7e83_row13_col1, #T_c7e83_row13_col2, #T_c7e83_row13_col3, #T_c7e83_row13_col4, #T_c7e83_row13_col5, #T_c7e83_row13_col6, #T_c7e83_row13_col7 {
#   text-align: left;
# }
# #T_c7e83_row0_col1, #T_c7e83_row0_col3, #T_c7e83_row0_col5, #T_c7e83_row1_col1, #T_c7e83_row1_col2, #T_c7e83_row1_col3, #T_c7e83_row1_col4, #T_c7e83_row1_col5, #T_c7e83_row1_col6, #T_c7e83_row1_col7, #T_c7e83_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c7e83_row0_col8, #T_c7e83_row1_col8, #T_c7e83_row2_col8, #T_c7e83_row3_col8, #T_c7e83_row4_col8, #T_c7e83_row5_col8, #T_c7e83_row6_col8, #T_c7e83_row7_col8, #T_c7e83_row8_col8, #T_c7e83_row9_col8, #T_c7e83_row10_col8, #T_c7e83_row11_col8, #T_c7e83_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c7e83_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c7e83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7e83_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c7e83_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c7e83_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c7e83_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c7e83_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c7e83_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c7e83_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c7e83_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c7e83_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7e83_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_c7e83_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_c7e83_row0_col1" class="data row0 col1" >0.9494</td>
#       <td id="T_c7e83_row0_col2" class="data row0 col2" >0.9923</td>
#       <td id="T_c7e83_row0_col3" class="data row0 col3" >0.9494</td>
#       <td id="T_c7e83_row0_col4" class="data row0 col4" >0.9496</td>
#       <td id="T_c7e83_row0_col5" class="data row0 col5" >0.9494</td>
#       <td id="T_c7e83_row0_col6" class="data row0 col6" >0.9200</td>
#       <td id="T_c7e83_row0_col7" class="data row0 col7" >0.9201</td>
#       <td id="T_c7e83_row0_col8" class="data row0 col8" >0.6330</td>
#     </tr>
#     <tr>
#       <th id="T_c7e83_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_c7e83_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c7e83_row1_col1" class="data row1 col1" >0.9494</td>
#       <td id="T_c7e83_row1_col2" class="data row1 col2" >0.9929</td>
#       <td id="T_c7e83_row1_col3" class="data row1 col3" >0.9494</td>
#       <td id="T_c7e83_row1_col4" class="data row1 col4" >0.9499</td>
#       <td id="T_c7e83_row1_col5" class="data row1 col5" >0.9494</td>
#       <td id="T_c7e83_row1_col6" class="data row1 col6" >0.9201</td>
#       <td id="T_c7e83_row1_col7" class="data row1 col7" >0.9203</td>
#       <td id="T_c7e83_row1_col8" class="data row1 col8" >21.8630</td>
#     </tr>
#     <tr>
#       <th id="T_c7e83_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_c7e83_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c7e83_row2_col1" class="data row2 col1" >0.9486</td>
#       <td id="T_c7e83_row2_col2" class="data row2 col2" >0.9929</td>
#       <td id="T_c7e83_row2_col3" class="data row2 col3" >0.9486</td>
#       <td id="T_c7e83_row2_col4" class="data row2 col4" >0.9489</td>
#       <td id="T_c7e83_row2_col5" class="data row2 col5" >0.9486</td>
#       <td id="T_c7e83_row2_col6" class="data row2 col6" >0.9188</td>
#       <td id="T_c7e83_row2_col7" class="data row2 col7" >0.9189</td>
#       <td id="T_c7e83_row2_col8" class="data row2 col8" >5.5200</td>
#     </tr>
#     <tr>
#       <th id="T_c7e83_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_c7e83_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_c7e83_row3_col1" class="data row3 col1" >0.9485</td>
#       <td id="T_c7e83_row3_col2" class="data row3 col2" >0.9916</td>
#       <td id="T_c7e83_row3_col3" class="data row3 col3" >0.9485</td>
#       <td id="T_c7e83_row3_col4" class="data row3 col4" >0.9488</td>
#       <td id="T_c7e83_row3_col5" class="data row3 col5" >0.9484</td>
#       <td id="T_c7e83_row3_col6" class="data row3 col6" >0.9184</td>
#       <td id="T_c7e83_row3_col7" class="data row3 col7" >0.9185</td>
#       <td id="T_c7e83_row3_col8" class="data row3 col8" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_c7e83_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_c7e83_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_c7e83_row4_col1" class="data row4 col1" >0.9479</td>
#       <td id="T_c7e83_row4_col2" class="data row4 col2" >0.9923</td>
#       <td id="T_c7e83_row4_col3" class="data row4 col3" >0.9479</td>
#       <td id="T_c7e83_row4_col4" class="data row4 col4" >0.9481</td>
#       <td id="T_c7e83_row4_col5" class="data row4 col5" >0.9478</td>
#       <td id="T_c7e83_row4_col6" class="data row4 col6" >0.9176</td>
#       <td id="T_c7e83_row4_col7" class="data row4 col7" >0.9177</td>
#       <td id="T_c7e83_row4_col8" class="data row4 col8" >0.2980</td>
#     </tr>
#     <tr>
#       <th id="T_c7e83_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_c7e83_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_c7e83_row5_col1" class="data row5 col1" >0.9444</td>
#       <td id="T_c7e83_row5_col2" class="data row5 col2" >0.9821</td>
#       <td id="T_c7e83_row5_col3" class="data row5 col3" >0.9444</td>
#       <td id="T_c7e83_row5_col4" class="data row5 col4" >0.9447</td>
#       <td id="T_c7e83_row5_col5" class="data row5 col5" >0.9443</td>
#       <td id="T_c7e83_row5_col6" class="data row5 col6" >0.9121</td>
#       <td id="T_c7e83_row5_col7" class="data row5 col7" >0.9123</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
holdout_preds = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b073d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b073d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b073d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b073d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b073d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b073d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b073d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b073d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b073d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b073d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b073d_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_b073d_row0_col1" class="data row0 col1" >0.9134</td>
#       <td id="T_b073d_row0_col2" class="data row0 col2" >0.9779</td>
#       <td id="T_b073d_row0_col3" class="data row0 col3" >0.9134</td>
#       <td id="T_b073d_row0_col4" class="data row0 col4" >0.9130</td>
#       <td id="T_b073d_row0_col5" class="data row0 col5" >0.9130</td>
#       <td id="T_b073d_row0_col6" class="data row0 col6" >0.8619</td>
#       <td id="T_b073d_row0_col7" class="data row0 col7" >0.8622</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Models Serialization
# Serializing feature extraction as well as ml classification models.

# %%
# best feature extraction icnn model
best_feature_extractor.save(
    os.path.join("..","..", "models", "updatedInception", "20_electrodes_4_classes_best_feature_extractor"),
    overwrite=True,
    include_optimizer=True,
    save_format="h5",
)

# %% [markdown]
# ## Data Serialization
# Serializing the processed train and holdout validation sets.

# %%
train_features_df.to_csv(os.path.join("..","..", "data", "finalized","updatedInception", "20_electrodes_4_classes_train_df.csv"), index=False)
holdout_features_df.to_csv(os.path.join("..","..", "data", "finalized","updatedInception", "20_electrodes_4_classes_holdout_df.csv"), index=False)

# %% [markdown]
# ## Ploting model
#
# ploting the confusion_matrix:

# %%
plot_model(
    best_model, 
    plot = 'confusion_matrix',
    use_train_data = False,
)

# %%
plot_model(
    best_model, 
    plot = 'learning'
)

# %%
plot_model(
    best_model, 
    plot = 'boundary'
)

# %% [markdown]
# ploting the learning curve:

# %%
plot_model(
    best_model, 
    plot = 'auc', 
    use_train_data = False,
)

# %%
plot_model(
    best_model, 
    plot = 'class_report', 
)
